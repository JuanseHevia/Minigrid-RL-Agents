# %% [markdown]
# # Assignment 5, Problem 1
#
# This is the starter code for Assignment 5, Problem 1.
#
# In this assignment, you will solve increasingly challenging tasks from the [Minigrid benchmark](https://minigrid.farama.org/).

# %%
# !pip install torch
# !pip install gymnasium==0.29.1
# !pip install minigrid==2.3.1
# !pip install stable-baselines3
# !pip install wandb
# !pip install tensorboard

# %%
import gymnasium as gym
import minigrid
import numpy as np

np.set_printoptions(formatter={'float': lambda x: "{0:0.2f}".format(x)})
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.9.20)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def compute_score(task, policy):
  num_episodes = 10
  cur_episode  = 0

  seed_by_episode = [42, 34, 50, 1, 9, 7, 43, 56, 90, 11]
  score_by_episode = np.zeros(num_episodes)

  while cur_episode < num_episodes:

    cumulative_reward = 0
    cur_seed = seed_by_episode[cur_episode]

    observation, info = task.reset(seed=cur_seed)
    done = False

    while not done:
      action = policy(observation)
      observation, reward, terminated, truncated, info = task.step(action)
      cumulative_reward += reward

      if terminated or truncated:
        done = True
        score_by_episode[cur_episode] = cumulative_reward
        cur_episode += 1

  score_mean = round(score_by_episode.mean(), 3)
  score_std  = round(score_by_episode.std(), 3)
  score_best = round(score_by_episode.max(), 3)

  print(f"Best score: {score_best}")
  print(f"Average score: {score_mean, score_std}")

  return score_by_episode

# %% [markdown]
# ## Problem 1
# Solve the [Minigrid Unlock](https://minigrid.farama.org/environments/minigrid/UnlockEnv/) task.
#
# This problem is worth 5 points.
#
# ![](https://minigrid.farama.org/_images/UnlockEnv.gif)

# %%
first_task = gym.make("MiniGrid-Unlock-v0")

# %%
obs, _ = first_task.reset()
print("Observation keys:", obs.keys())
print("Image shape:", obs['image'].shape)
print("Direction:", obs["direction"])
print("Mission:", obs["mission"])
print("Action space:", first_task.action_space)
# Out:
# Observation keys: dict_keys(['image', 'direction', 'mission'])
# Image shape: (7, 7, 3)
# Direction: 3
# Mission: open the door
# Action space: Discrete(7)

# %% [markdown]
# # Training

# %% [markdown]
# ## Define feature extractor
# Minigrid does not comply with SB3's off-the-shelf CnnPolicy

# %%
import torch
import torch.nn as nn
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

class MinigridFeaturesExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space: gym.Space, features_dim: int = 512,
                  normalized_image: bool = False) -> None:
        super().__init__(observation_space, features_dim)
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 16, (2, 2)),
            nn.ReLU(),
            nn.Conv2d(16, 32, (2, 2)),
            nn.ReLU(),
            nn.Conv2d(32, 64, (2, 2)),
            nn.ReLU(),
            nn.Flatten(),
        )

        # Compute shape by doing one forward pass
        with torch.no_grad():
            n_flatten = self.cnn(torch.as_tensor(observation_space.sample()[None]).float()).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))

# %%
######## PUT YOUR CODE HERE ########
from minigrid.wrappers import ImgObsWrapper
from stable_baselines3 import PPO
from wandb.integration.sb3 import WandbCallback
import wandb

# setup config
_config = {
    "policy": "CnnPolicy",
    "env": "MiniGrid-Unlock-v0",
    "total_timesteps": 5e5,
    "features_dim": 128,
}

## initialize wandb project
run = wandb.init(project="COMP552-A5-minigrid",
           entity="jh216",
           config=_config,
           sync_tensorboard=True,
           monitor_gym=True)

policy_kwargs = dict(
    features_extractor_class=MinigridFeaturesExtractor,
    features_extractor_kwargs=dict(features_dim=_config["features_dim"]),
)

env = gym.make("MiniGrid-Unlock-v0", render_mode="rgb_array")
env = ImgObsWrapper(env)

model = PPO("CnnPolicy", env, policy_kwargs=policy_kwargs, verbose=1,
            tensorboard_log=f"runs/{run.id}")
model.learn(_config["total_timesteps"], callback=WandbCallback(
    model_save_path=f"models/P1/{run.id}",
    verbose=2,
))

model.save(f"models/{run.id}")
run.finish()
######## PUT YOUR CODE HERE ########
# Out:
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/Users/juansegundohevia/Documents/RiceMDS/COMP552/HW5/wandb/run-20241204_105126-3if0m4yk</code>
# Syncing run <strong><a href='https://wandb.ai/jh216/COMP552-A5-minigrid/runs/3if0m4yk' target="_blank">magic-donkey-4</a></strong> to <a href='https://wandb.ai/jh216/COMP552-A5-minigrid' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/jh216/COMP552-A5-minigrid' target="_blank">https://wandb.ai/jh216/COMP552-A5-minigrid</a>
#  View run at <a href='https://wandb.ai/jh216/COMP552-A5-minigrid/runs/3if0m4yk' target="_blank">https://wandb.ai/jh216/COMP552-A5-minigrid/runs/3if0m4yk</a>
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to runs/3if0m4yk/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 255      |
# |    ep_rew_mean     | 0.114    |
# | time/              |          |
# |    fps             | 2145     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 271           |
# |    ep_rew_mean          | 0.061         |
# | time/                   |               |
# |    fps                  | 1078          |
# |    iterations           | 2             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.011851428   |
# |    clip_fraction        | 0.0655        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0034515858 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0147        |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.0034       |
# |    value_loss           | 0.00331       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 276         |
# |    ep_rew_mean          | 0.0416      |
# | time/                   |             |
# |    fps                  | 890         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012207158 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | -3.2030597  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00516    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00936    |
# |    value_loss           | 6.61e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 279         |
# |    ep_rew_mean          | 0.0316      |
# | time/                   |             |
# |    fps                  | 839         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010065235 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | -0.5638075  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00326    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00654    |
# |    value_loss           | 3.23e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 281         |
# |    ep_rew_mean          | 0.0254      |
# | time/                   |             |
# |    fps                  | 823         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012354471 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | -5.0135674  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0251     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 2.24e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 282         |
# |    ep_rew_mean          | 0.0213      |
# | time/                   |             |
# |    fps                  | 827         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012797909 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | -2.5086644  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00389    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 3.83e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 283         |
# |    ep_rew_mean          | 0.0183      |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 7           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014386887 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | -3.5370007  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0412     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 2.6e-05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 280         |
# |    ep_rew_mean          | 0.0295      |
# | time/                   |             |
# |    fps                  | 801         |
# |    iterations           | 8           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009752271 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | -6.9462094  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0058     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 2.68e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 280          |
# |    ep_rew_mean          | 0.0321       |
# | time/                   |              |
# |    fps                  | 805          |
# |    iterations           | 9            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.009778881  |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.83        |
# |    explained_variance   | -0.014440417 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000321     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.008       |
# |    value_loss           | 0.00133      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 276         |
# |    ep_rew_mean          | 0.0447      |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 10          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011909844 |
# |    clip_fraction        | 0.0968      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | -0.06992495 |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.012      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00613    |
# |    value_loss           | 0.000636    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 275         |
# |    ep_rew_mean          | 0.0506      |
# | time/                   |             |
# |    fps                  | 758         |
# |    iterations           | 11          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012143202 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.028007269 |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00348    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.00325     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 276        |
# |    ep_rew_mean          | 0.0466     |
# | time/                   |            |
# |    fps                  | 748        |
# |    iterations           | 12         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01093731 |
# |    clip_fraction        | 0.0928     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.83      |
# |    explained_variance   | 0.03353262 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0127    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00651   |
# |    value_loss           | 0.00285    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 274         |
# |    ep_rew_mean          | 0.0509      |
# | time/                   |             |
# |    fps                  | 716         |
# |    iterations           | 13          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009026816 |
# |    clip_fraction        | 0.095       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | -1.449873   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00326     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00639    |
# |    value_loss           | 9.75e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 275         |
# |    ep_rew_mean          | 0.0489      |
# | time/                   |             |
# |    fps                  | 715         |
# |    iterations           | 14          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011966135 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.04639876  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0207     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00671    |
# |    value_loss           | 0.00246     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 275         |
# |    ep_rew_mean          | 0.0501      |
# | time/                   |             |
# |    fps                  | 712         |
# |    iterations           | 15          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010957493 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | -0.06611347 |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0146     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.00315     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 275         |
# |    ep_rew_mean          | 0.0501      |
# | time/                   |             |
# |    fps                  | 701         |
# |    iterations           | 16          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012167095 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | -0.55784273 |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0154     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.000116    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 273         |
# |    ep_rew_mean          | 0.058       |
# | time/                   |             |
# |    fps                  | 695         |
# |    iterations           | 17          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.012207046 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | -0.6456411  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0233     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 8.54e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 271          |
# |    ep_rew_mean          | 0.0671       |
# | time/                   |              |
# |    fps                  | 697          |
# |    iterations           | 18           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0127349775 |
# |    clip_fraction        | 0.151        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.047929585  |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00264     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00819     |
# |    value_loss           | 0.0016       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 266         |
# |    ep_rew_mean          | 0.0852      |
# | time/                   |             |
# |    fps                  | 700         |
# |    iterations           | 19          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010444378 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.04956132  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0165     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00488    |
# |    value_loss           | 0.00237     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 265          |
# |    ep_rew_mean          | 0.09         |
# | time/                   |              |
# |    fps                  | 702          |
# |    iterations           | 20           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.012843588  |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.65        |
# |    explained_variance   | -0.009398222 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0151       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00986     |
# |    value_loss           | 0.00343      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 264         |
# |    ep_rew_mean          | 0.0929      |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 21          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.013944652 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.025928259 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0148      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0099     |
# |    value_loss           | 0.000973    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 263          |
# |    ep_rew_mean          | 0.0976       |
# | time/                   |              |
# |    fps                  | 709          |
# |    iterations           | 22           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0127961505 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.55        |
# |    explained_variance   | 0.14567918   |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0201      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0076      |
# |    value_loss           | 0.0023       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 264         |
# |    ep_rew_mean          | 0.0935      |
# | time/                   |             |
# |    fps                  | 711         |
# |    iterations           | 23          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.012482824 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.076168776 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.022       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00854    |
# |    value_loss           | 0.00297     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 255         |
# |    ep_rew_mean          | 0.128       |
# | time/                   |             |
# |    fps                  | 711         |
# |    iterations           | 24          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.013345445 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.0713048   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000335   |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00916    |
# |    value_loss           | 0.00117     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | 0.145       |
# | time/                   |             |
# |    fps                  | 711         |
# |    iterations           | 25          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.012220534 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.14654619  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0087      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00912    |
# |    value_loss           | 0.00948     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 252         |
# |    ep_rew_mean          | 0.142       |
# | time/                   |             |
# |    fps                  | 712         |
# |    iterations           | 26          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008069066 |
# |    clip_fraction        | 0.092       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.22591329  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0356     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.00336     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 244         |
# |    ep_rew_mean          | 0.17        |
# | time/                   |             |
# |    fps                  | 712         |
# |    iterations           | 27          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.012706617 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.2073263   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.012      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.00176     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 238         |
# |    ep_rew_mean          | 0.193       |
# | time/                   |             |
# |    fps                  | 713         |
# |    iterations           | 28          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.014419597 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.19694382  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0361     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.00577     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | 0.203       |
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 29          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008058905 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.24607724  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00323    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00247    |
# |    value_loss           | 0.00355     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 234         |
# |    ep_rew_mean          | 0.21        |
# | time/                   |             |
# |    fps                  | 715         |
# |    iterations           | 30          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008676314 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.341263    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0234     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00904    |
# |    value_loss           | 0.00171     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 233          |
# |    ep_rew_mean          | 0.215        |
# | time/                   |              |
# |    fps                  | 717          |
# |    iterations           | 31           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0073316074 |
# |    clip_fraction        | 0.0998       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.34727544   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0127       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00403     |
# |    value_loss           | 0.0034       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 229          |
# |    ep_rew_mean          | 0.229        |
# | time/                   |              |
# |    fps                  | 719          |
# |    iterations           | 32           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.011630829  |
# |    clip_fraction        | 0.139        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -0.021013498 |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0221      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0059      |
# |    value_loss           | 0.00428      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | 0.219       |
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 33          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.025830692 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.32465333  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0439     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00887    |
# |    value_loss           | 0.00141     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | 0.23        |
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 34          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.013041539 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.8458353  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.025       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 0.000331    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | 0.236       |
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 35          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012565267 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.18670118  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000379    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 0.00541     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 0.242        |
# | time/                   |              |
# |    fps                  | 720          |
# |    iterations           | 36           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0123706665 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.21428204   |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00403     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0062      |
# |    value_loss           | 0.00767      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 0.25        |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 37          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.010583507 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.045885563 |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0246     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00972    |
# |    value_loss           | 0.00444     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 222         |
# |    ep_rew_mean          | 0.255       |
# | time/                   |             |
# |    fps                  | 717         |
# |    iterations           | 38          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.010990586 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.40247542  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00675     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00849    |
# |    value_loss           | 0.00439     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 220         |
# |    ep_rew_mean          | 0.26        |
# | time/                   |             |
# |    fps                  | 715         |
# |    iterations           | 39          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008991111 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.43997622  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0257     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.00503     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 211         |
# |    ep_rew_mean          | 0.293       |
# | time/                   |             |
# |    fps                  | 711         |
# |    iterations           | 40          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.017534668 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.35060412  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0234     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.00382     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 199        |
# |    ep_rew_mean          | 0.333      |
# | time/                   |            |
# |    fps                  | 708        |
# |    iterations           | 41         |
# |    time_elapsed         | 118        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.01178408 |
# |    clip_fraction        | 0.154      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.4267097  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0165     |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00642   |
# |    value_loss           | 0.00657    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 181         |
# |    ep_rew_mean          | 0.396       |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 42          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.009099644 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.3938533   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0181     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00785    |
# |    value_loss           | 0.0113      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | 0.428       |
# | time/                   |             |
# |    fps                  | 696         |
# |    iterations           | 43          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.017829228 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.52528596  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00448     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.00749     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | 0.52        |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 44          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008090002 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.45488983  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00356     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00503    |
# |    value_loss           | 0.00877     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | 0.589       |
# | time/                   |             |
# |    fps                  | 682         |
# |    iterations           | 45          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.013240946 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.52190864  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0452     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00792    |
# |    value_loss           | 0.0115      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 118          |
# |    ep_rew_mean          | 0.617        |
# | time/                   |              |
# |    fps                  | 678          |
# |    iterations           | 46           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0143386405 |
# |    clip_fraction        | 0.15         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.5875319    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0152      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0114      |
# |    value_loss           | 0.0087       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 114         |
# |    ep_rew_mean          | 0.634       |
# | time/                   |             |
# |    fps                  | 674         |
# |    iterations           | 47          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010467976 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.5551614   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0175      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00802    |
# |    value_loss           | 0.00945     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | 0.671       |
# | time/                   |             |
# |    fps                  | 671         |
# |    iterations           | 48          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.022346638 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.5073678   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0125     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 0.00811     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.5        |
# |    ep_rew_mean          | 0.692       |
# | time/                   |             |
# |    fps                  | 671         |
# |    iterations           | 49          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011132551 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.44276685  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.037      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.011       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.7        |
# |    ep_rew_mean          | 0.695       |
# | time/                   |             |
# |    fps                  | 667         |
# |    iterations           | 50          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.010221684 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.32101315  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0145     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00817    |
# |    value_loss           | 0.014       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.9        |
# |    ep_rew_mean          | 0.704       |
# | time/                   |             |
# |    fps                  | 662         |
# |    iterations           | 51          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.016296964 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.5102457   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0221     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00956    |
# |    value_loss           | 0.00847     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.2        |
# |    ep_rew_mean          | 0.737       |
# | time/                   |             |
# |    fps                  | 656         |
# |    iterations           | 52          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.019022703 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.4591846   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0398     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.0114      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.6        |
# |    ep_rew_mean          | 0.766       |
# | time/                   |             |
# |    fps                  | 652         |
# |    iterations           | 53          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.014334891 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.482306    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0101     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00832    |
# |    value_loss           | 0.0129      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.8        |
# |    ep_rew_mean          | 0.782       |
# | time/                   |             |
# |    fps                  | 647         |
# |    iterations           | 54          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.013251621 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# ...
# |    value_loss           | 0.00128     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.6       |
# |    ep_rew_mean          | 0.957      |
# | time/                   |            |
# |    fps                  | 283        |
# |    iterations           | 84         |
# |    time_elapsed         | 607        |
# |    total_timesteps      | 172032     |
# | train/                  |            |
# |    approx_kl            | 0.09461363 |
# |    clip_fraction        | 0.19       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.265     |
# |    explained_variance   | 0.5417979  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0123     |
# |    n_updates            | 830        |
# |    policy_gradient_loss | -0.0102    |
# |    value_loss           | 0.00137    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.1        |
# |    ep_rew_mean          | 0.962       |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 85          |
# |    time_elapsed         | 610         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.029118925 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.271      |
# |    explained_variance   | 0.56319505  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0293     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 0.00319     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.3        |
# |    ep_rew_mean          | 0.958       |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 86          |
# |    time_elapsed         | 613         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.038225655 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.217      |
# |    explained_variance   | 0.5215446   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00255     |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.00831    |
# |    value_loss           | 0.00101     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.9        |
# |    ep_rew_mean          | 0.963       |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 87          |
# |    time_elapsed         | 616         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.058036603 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.233      |
# |    explained_variance   | 0.55836356  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0279      |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 0.0017      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.9        |
# |    ep_rew_mean          | 0.96        |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 88          |
# |    time_elapsed         | 618         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.055527918 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.216      |
# |    explained_variance   | 0.64326775  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0204     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00877    |
# |    value_loss           | 0.000886    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.3       |
# |    ep_rew_mean          | 0.962      |
# | time/                   |            |
# |    fps                  | 293        |
# |    iterations           | 89         |
# |    time_elapsed         | 621        |
# |    total_timesteps      | 182272     |
# | train/                  |            |
# |    approx_kl            | 0.04842835 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.218     |
# |    explained_variance   | 0.57978487 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0127    |
# |    n_updates            | 880        |
# |    policy_gradient_loss | -0.00989   |
# |    value_loss           | 0.00105    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.2       |
# |    ep_rew_mean          | 0.962      |
# | time/                   |            |
# |    fps                  | 295        |
# |    iterations           | 90         |
# |    time_elapsed         | 624        |
# |    total_timesteps      | 184320     |
# | train/                  |            |
# |    approx_kl            | 0.04827477 |
# |    clip_fraction        | 0.187      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.236     |
# |    explained_variance   | 0.61764294 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0267    |
# |    n_updates            | 890        |
# |    policy_gradient_loss | -0.00428   |
# |    value_loss           | 0.000996   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11          |
# |    ep_rew_mean          | 0.966       |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 91          |
# |    time_elapsed         | 627         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.071661904 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.19       |
# |    explained_variance   | 0.61454594  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0129     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.000967    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.6        |
# |    ep_rew_mean          | 0.961       |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 92          |
# |    time_elapsed         | 629         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.039428197 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.19       |
# |    explained_variance   | 0.5787725   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0111     |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0036     |
# |    value_loss           | 0.00123     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.8       |
# |    ep_rew_mean          | 0.963      |
# | time/                   |            |
# |    fps                  | 301        |
# |    iterations           | 93         |
# |    time_elapsed         | 632        |
# |    total_timesteps      | 190464     |
# | train/                  |            |
# |    approx_kl            | 0.07234399 |
# |    clip_fraction        | 0.121      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.186     |
# |    explained_variance   | 0.5721703  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00681   |
# |    n_updates            | 920        |
# |    policy_gradient_loss | -0.00733   |
# |    value_loss           | 0.00233    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13         |
# |    ep_rew_mean          | 0.959      |
# | time/                   |            |
# |    fps                  | 302        |
# |    iterations           | 94         |
# |    time_elapsed         | 635        |
# |    total_timesteps      | 192512     |
# | train/                  |            |
# |    approx_kl            | 0.03944212 |
# |    clip_fraction        | 0.139      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.205     |
# |    explained_variance   | 0.41826427 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00495   |
# |    n_updates            | 930        |
# |    policy_gradient_loss | -0.00539   |
# |    value_loss           | 0.00101    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.6       |
# |    ep_rew_mean          | 0.964      |
# | time/                   |            |
# |    fps                  | 304        |
# |    iterations           | 95         |
# |    time_elapsed         | 638        |
# |    total_timesteps      | 194560     |
# | train/                  |            |
# |    approx_kl            | 0.1776564  |
# |    clip_fraction        | 0.146      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.16      |
# |    explained_variance   | 0.26391578 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0281    |
# |    n_updates            | 940        |
# |    policy_gradient_loss | -0.0149    |
# |    value_loss           | 0.00209    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14.2       |
# |    ep_rew_mean          | 0.956      |
# | time/                   |            |
# |    fps                  | 306        |
# |    iterations           | 96         |
# |    time_elapsed         | 641        |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.07645812 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.151     |
# |    explained_variance   | 0.48875684 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0185    |
# |    n_updates            | 950        |
# |    policy_gradient_loss | -0.000778  |
# |    value_loss           | 0.00104    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.9        |
# |    ep_rew_mean          | 0.963       |
# | time/                   |             |
# |    fps                  | 308         |
# |    iterations           | 97          |
# |    time_elapsed         | 644         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.034903146 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.187      |
# |    explained_variance   | 0.26598012  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0233     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0212     |
# |    value_loss           | 0.00128     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.5        |
# |    ep_rew_mean          | 0.964       |
# | time/                   |             |
# |    fps                  | 310         |
# |    iterations           | 98          |
# |    time_elapsed         | 647         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.047325607 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.171      |
# |    explained_variance   | 0.5106963   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0209      |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0097     |
# |    value_loss           | 0.000821    |
# -----------------------------------------
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>rollout/ep_len_mean</td><td>▇██████▇▇▇▇▇▇▇▇▆▆▆▅▄▄▃▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▃▃▃▄▅▅▆▆▆▇▇██████████████</td></tr><tr><td>time/fps</td><td>█▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/approx_kl</td><td>▁▂▁▁▁▁▁▂▂▂▁▁▂▁▃▁▁▁▁▁▃▁▂▂▂▂▂▃▄▃▃▃▃▃▃▇▆▅█▄</td></tr><tr><td>train/clip_fraction</td><td>▄▁▄▂█▂▇▅▄▅▄▅▅▅▅█▃▅▃▆▇▆▆▆▆▆▆█▅▄▆▇▃▅▄▄█▆▄▅</td></tr><tr><td>train/clip_range</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▂▂▂▂▃▃▄▄▄▄▄▅▄▄▅▅▅▅▅▅▅▆▆▆▇▇▇▇██████</td></tr><tr><td>train/explained_variance</td><td>▇▁▆▂▇▇▆▇▇▇▇▇▇▇▅█▇██████▇████████████████</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▇▅▃▁▅▆▄▄▇▃▅▄▂▅▃▅▅▆▃▇▄▃▁▆▇▆▁▃▅▃▇▇▅▅▄▂█▂▄▃</td></tr><tr><td>train/policy_gradient_loss</td><td>▄▂▃▃▆▄▇▄▂▅▅▅▄▄▇▇▅▄▇▇▄▆▅▆▆▄▃▂▃▁▅█▇▇▂▆▂▅▆▅</td></tr><tr><td>train/value_loss</td><td>▁▁▂▂▁▂▂▃▂▂▂▁▄▃▃▄▆▄▅▅▇▆▆█▆▂▂▂▂▂▂▂▂▂▂▁▁▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>200704</td></tr><tr><td>rollout/ep_len_mean</td><td>11.53</td></tr><tr><td>rollout/ep_rew_mean</td><td>0.96397</td></tr><tr><td>time/fps</td><td>310</td></tr><tr><td>train/approx_kl</td><td>0.04733</td></tr><tr><td>train/clip_fraction</td><td>0.14561</td></tr><tr><td>train/clip_range</td><td>0.2</td></tr><tr><td>train/entropy_loss</td><td>-0.17132</td></tr><tr><td>train/explained_variance</td><td>0.5107</td></tr><tr><td>train/learning_rate</td><td>0.0003</td></tr><tr><td>train/loss</td><td>0.02092</td></tr><tr><td>train/policy_gradient_loss</td><td>-0.0097</td></tr><tr><td>train/value_loss</td><td>0.00082</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">magic-donkey-4</strong> at: <a href='https://wandb.ai/jh216/COMP552-A5-minigrid/runs/3if0m4yk' target="_blank">https://wandb.ai/jh216/COMP552-A5-minigrid/runs/3if0m4yk</a><br/> View project at: <a href='https://wandb.ai/jh216/COMP552-A5-minigrid' target="_blank">https://wandb.ai/jh216/COMP552-A5-minigrid</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 2 other file(s)
# Find logs at: <code>./wandb/run-20241204_105126-3if0m4yk/logs</code>

# %%
def first_policy(observation):
  ######## PUT YOUR CODE HERE ########
  action, _ = model.predict(observation["image"])

  ######## PUT YOUR CODE HERE ########
  return action

# %%
scores = compute_score(task=first_task, policy=first_policy)
# Out:
# Best score: 0.984
# Average score: (np.float64(0.967), np.float64(0.013))

# %%
print(f"Points awarded: {10*max(max(scores) - 0.3, 0)}")
# Out:
# Points awarded: 6.84375
